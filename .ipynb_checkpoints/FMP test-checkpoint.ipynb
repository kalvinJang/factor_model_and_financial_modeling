# %%
pip install fmp_python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from fmp_python.fmp import FMP
api_key = '8ede72aa30eb534c51f15eaa71ff2e05'

fmp = FMP(api_key=api_key, output_format='pandas', write_to_file=True)
fmp.get_quote('MPAY')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
fmp.get_quote_short('MVP')
# Out:
#   symbol   price  volume
# 0    MVP  12.325    1027

# %%
fmp.get_historical_chart('1min','TSLA')
# Out:
#                     date      open     low      high     close  volume
# 0    2022-06-23 09:38:00  696.2300  695.99  698.6999  696.0000  192155
# 1    2022-06-23 09:37:00  702.3500  695.55  702.4910  695.9900  379352
# 2    2022-06-23 09:36:00  701.9396  701.27  704.3500  702.3301  189154
# 3    2022-06-23 09:35:00  708.0550  701.17  708.4599  701.9300  319385
# 4    2022-06-23 09:34:00  709.7630  707.92  711.8828  708.2600  158089
# ..                   ...       ...     ...       ...       ...     ...
# 663  2022-06-21 11:37:00  719.8200  718.58  720.2753  718.7358  114368
# 664  2022-06-21 11:36:00  721.2801  719.37  721.4950  719.8446   84974
# 665  2022-06-21 11:35:00  720.5610  719.65  722.0050  721.5333  143281
# 666  2022-06-21 11:34:00  722.4500  720.55  722.4500  720.8585  124092
# 667  2022-06-21 11:33:00  722.2900  721.88  722.7400  722.3400   77260
#
# [668 rows x 6 columns]

# %%
try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import certifi
import json

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v3/financial-statement-symbol-lists?apikey=8ede72aa30eb534c51f15eaa71ff2e05")
print(len(get_jsonparsed_data(url)))
# Out:
# C:\Users\jky93\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
# 38212

# %%
import pandas as pd
url = "https://financialmodelingprep.com/api/v3/balance-sheet-statement/AAPL?apikey=8ede72aa30eb534c51f15eaa71ff2e05&limit=300"
pd.DataFrame(get_jsonparsed_data(url))
# Out:
# C:\Users\jky93\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#          date symbol reportedCurrency         cik fillingDate  \
# 0  2021-09-25   AAPL              USD  0000320193  2021-10-29
# 1  2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2  2019-09-28   AAPL              USD  0000320193  2019-10-31
# 3  2018-09-29   AAPL              USD  0000320193  2018-11-05
# 4  2017-09-30   AAPL              USD  0000320193  2017-11-03
#
#           acceptedDate calendarYear period  cashAndCashEquivalents  \
# 0  2021-10-28 18:04:28         2021     FY             34940000000
# 1  2020-10-29 18:06:25         2020     FY             38016000000
# 2  2019-10-30 18:12:36         2019     FY             48844000000
# 3  2018-11-05 08:01:40         2018     FY             25913000000
# 4  2017-11-03 08:01:37         2017     FY             20289000000
#
# ...

# %%
url = 'https://financialmodelingprep.com/api/v3/cash-flow-statement/TSLA?apikey=8ede72aa30eb534c51f15eaa71ff2e05&limit=500'
pd.DataFrame(get_jsonparsed_data(url))
# Out:
# C:\Users\jky93\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#          date symbol reportedCurrency         cik fillingDate  \
# 0  2021-12-31   TSLA              USD  0001318605  2022-02-07
# 1  2020-12-31   TSLA              USD  0001318605  2021-02-08
# 2  2019-12-31   TSLA              USD  0001318605  2020-02-13
# 3  2018-12-31   TSLA              USD  0001318605  2019-02-19
# 4  2017-12-31   TSLA              USD  0001318605  2018-02-23
#
#           acceptedDate calendarYear period   netIncome  \
# 0  2022-02-04 20:11:27         2021     FY  5519000000
# 1  2021-02-08 07:27:23         2020     FY   690000000
# 2  2020-02-13 07:12:18         2019     FY  -862000000
# 3  2019-02-19 06:10:16         2018     FY  -976091000
# 4  2018-02-23 06:07:43         2017     FY -1961400000
#
#    depreciationAndAmortization  ...  netCashUsedProvidedByFinancingActivities  \
# ...

# %%
result = []
for i in range(10):
    url = "https://financialmodelingprep.com/api/v3/delisted-companies?page="+str(i)+"&apikey=8ede72aa30eb534c51f15eaa71ff2e05"
    result.append(get_jsonparsed_data(url))
pd.DataFrame(result[0])
# Out:
# C:\Users\jky93\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#    symbol                                        companyName   exchange  \
# 0     MVP           Roundhill Pro Sports Media & Apparel ETF  NYSE ARCA
# 1    JPNL          DIREXION DAILY MSCI JAPAN BULL 3X SHARES   NYSE ARCA
# 2     KNL                                          Knoll Inc       NYSE
# 3    IRCP                  Irsa Propiedades Comerciales S.A.     NASDAQ
# 4    CYPS                                     Cyclo3pss Corp     NASDAQ
# ..    ...                                                ...        ...
# 95  TUGCU  SAI.TECH Global Corporation - Units (1 Ord Sha...     NASDAQ
# 96   WTRU                            Essential Utilities Inc       NYSE
# 97   BIGY                     Defiance Next Gen Big Data ETF  NYSE ARCA
# 98  GWGHQ                                   GWG Holdings Inc     NASDAQ
# ...

# %%
pd.DataFrame(result[1])
# Out:
#    symbol                                        companyName   exchange  \
# 0   ATSPT      SoundHound AI Inc - Subunit (1 Ord & 1/4 War)     NASDAQ
# 1    BUDX                                Cannabis Growth ETF  NYSE ARCA
# 2    VOLT                      Volt Information Sciences Inc   NYSE MKT
# 3   CHPMW            CHP Merger Corp - Warrants (22/11/2024)     NASDAQ
# 4   CHPMU  CHP Merger Corp - Units (1 Ord Class A & 1/2 War)     NASDAQ
# ..    ...                                                ...        ...
# 95   ECCY                     Eagle Point Credit Company Inc       NYSE
# 96  NXU-U  Energy Vault Holdings Inc - Units (1 Ord Share...       NYSE
# 97  GCACU  Cepton Inc - Units (1 Ord Share Class A & 1/2 ...     NASDAQ
# 98  SBEAU    BRC Inc - Units (1 Ord Share Class A & 1/3 War)     NASDAQ
# 99   CCAC                     Quanergy Systems Inc - Class A       NYSE
#
#        ipoDate delistedDate
# 0   2021-04-23   2022-04-27
# 1   2021-09-27   2022-04-25
# ...

# %%
import pandas as pd

# %%
code = 'AAPL'
api_key = '8ede72aa30eb534c51f15eaa71ff2e05'
url = "https://financialmodelingprep.com/api/v3/financial-growth/{}?apikey={}".format(code, api_key)
pd_g = pd.read_json(url)
growth_rate = np.mean(pd_g['dividendsperShareGrowth'].iloc[:10])

# %%
growth_rate
# Out:
# 0     0.067451
# 1     0.061635
# 2     0.104947
# 3     0.130598
# 4     0.102027
# 5     0.105235
# 6     0.099086
# 7     0.120997
# 8     3.289513
# 9     0.000000
# 10    0.000000
# 11    0.000000
# 12    0.000000
# 13    0.000000
# 14    0.000000
# 15    0.000000
# 16    0.000000
# 17    0.000000
# 18    0.000000
# 19    0.000000
# 20    0.000000
# 21    0.000000
# 22    0.000000
# 23    0.000000
# 24   -1.000000
# 25   -0.759961
# 26   -0.010686
# 27    0.002846
# 28    0.015094
# 29   -0.005292
# 30    0.098790
# 31    0.091834
# 32    0.000000
# 33    0.000000
# 34    0.000000
# 35    0.000000
# 36    0.000000
# Name: dividendsperShareGrowth, dtype: float64
